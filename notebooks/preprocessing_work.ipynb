# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
from string import ascii_letters
from rapidfuzz import process, fuzz
import matplotlib.pyplot as plt
import datetime as dt
import requests
from lxml import html
import math
import re
import json
import os

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 10)

# %%
raw_ld_df = pd.read_csv("data/raw_loan_data_date.csv", low_memory = False)
raw_ld_df.head()
# Out:
#                     BORROWER_NAME                 CITY STATE    ZIP  \
# 0            SHANGRI LA HOTEL INC  ELLENVILLE      N Y    NY  12428
# 1              CATSKILL MILLS INC           WALTON N Y    NY  13856
# 2           TRYON COATS & LEATHER   JOHNSTOWN       NY   NaN      0
# 3  LOUIS GELBER & ELSIE RODRIGUEZ             BROOKLYN    NY  11029
# 4                CHARLENE R PAYNE             BOGALUSA    LA  70427
#
#                              BANK BANK_STATE  INDUSTRY_ID APPROVAL_DATE  \
# 0      BANK OF AMERICA NATL ASSOC         NY            0      7-Dec-61
# 1  NBT BANK, NATIONAL ASSOCIATION         NY            0     27-Nov-64
# 2    KEYBANK NATIONAL ASSOCIATION         NY            0     18-May-66
# 3  GOVERNMENT DEVEL BK FOR PUERTO         PR            0     28-Feb-67
# 4                    WHITNEY BANK         MS            0     25-Apr-67
#
#   APPROVAL_YEAR  TERM  EMPLOYEE_COUNT  IS_NEW  JOBS_CREATED_COUNT  \
# 0          1962   300               0     0.0                   0
# 1          1965   252               0     0.0                   0
# 2          1966   282               0     0.0                   0
# 3          1967    72               0     0.0                   0
# 4          1967   228               4     0.0                   0
#
#    JOBS_RETAINED_COUNT  FRANCHISE_CODE  IS_URBAN IS_REVOLVER IS_LOW_DOC  \
# 0                    0               0         0           N          N
# 1                    0               0         0           N          N
# 2                    0               0         0           N          N
# 3                    0               0         0           N          N
# 4                    0               0         0           N          N
#
#   DEFAULT_DATE DISBURSEMENT_DATE DISBURSEMENT_AMOUNT BALANCE_AMOUNT  \
# 0    16-Feb-90               NaN              $0.00          $0.00
# 1     3-Apr-89               NaN              $0.00          $0.00
# 2    29-Mar-90         16-Aug-66         $60,000.00          $0.00
# 3    19-May-92               NaN              $0.00          $0.00
# 4    15-Mar-89               NaN              $0.00          $0.00
#
#   LOAN_STATUS CHARGE_OFF_AMOUNT   LOAN_AMOUNT SBA_APPROVED_AMOUNT  \
# 0         NaN        $2,613.00   $100,000.00          $90,000.00
# 1         NaN       $55,625.00   $150,000.00         $127,500.00
# 2      CHGOFF        $6,084.00    $60,000.00          $54,000.00
# 3         NaN        $8,023.00    $30,000.00          $15,000.00
# 4         NaN        $9,915.00    $45,000.00          $40,500.00
#
#    TREASURY_YIELD  CPI_INDEX        GDP  MORTGAGE_30_US_FIXED    UNRATE  \
# 0        3.945833  30.253333  603.92150                   NaN  5.566667
# 1        4.282500  31.528333  742.29025                   NaN  4.508333
# 2        4.923333  32.470833  813.41375                   NaN  3.791667
# 3        5.073333  33.375000  859.95625                   NaN  3.841667
# 4             NaN        NaN        NaN                   NaN       NaN
#
#    INDPRO_INDEX  UMCSENT_INDEX  CSUSHPINSA_INDEX  CP_INDEX  FEDFUNDS_RATE
# 0     25.332875         95.475               NaN  35.90825       2.708333
# 1     31.546817        103.425               NaN  53.34175       4.075000
# 2     34.337933         93.800               NaN  58.15200       5.111667
# 3     35.079150         94.975               NaN  56.61175       4.220000
# 4           NaN            NaN               NaN       NaN            NaN

# %%
unprocessed_ld_df = raw_ld_df.copy()
unprocessed_ld_df.dtypes
# Out:
# BORROWER_NAME        object
# CITY                 object
# STATE                object
# ZIP                   int64
# BANK                 object
#                      ...
# INDPRO_INDEX        float64
# UMCSENT_INDEX       float64
# CSUSHPINSA_INDEX    float64
# CP_INDEX            float64
# FEDFUNDS_RATE       float64
# Length: 36, dtype: object

# %%
def adjust_year(dt):
    return dt.replace(year=dt.year - 100) if dt.year >= 2025 else dt

date_format = "%d-%b-%y"
date_cols = ["APPROVAL_DATE", "DISBURSEMENT_DATE", "DEFAULT_DATE"]
for col in date_cols:
    unprocessed_ld_df[col] = unprocessed_ld_df[col].astype("string")
    unprocessed_ld_df[col] = pd.to_datetime(unprocessed_ld_df[col], format=date_format)
    unprocessed_ld_df[col] = unprocessed_ld_df[col].apply(adjust_year)
unprocessed_ld_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 899164 entries, 0 to 899163
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   BORROWER_NAME         899150 non-null  object
#  1   CITY                  899134 non-null  object
#  2   STATE                 899150 non-null  object
#  3   ZIP                   899164 non-null  int64
#  4   BANK                  897605 non-null  object
#  5   BANK_STATE            897598 non-null  object
#  6   INDUSTRY_ID           899164 non-null  int64
#  7   APPROVAL_DATE         899164 non-null  datetime64[ns]
#  8   APPROVAL_YEAR         899164 non-null  object
#  9   TERM                  899164 non-null  int64
#  10  EMPLOYEE_COUNT        899164 non-null  int64
#  11  IS_NEW                899028 non-null  float64
#  12  JOBS_CREATED_COUNT    899164 non-null  int64
#  13  JOBS_RETAINED_COUNT   899164 non-null  int64
#  14  FRANCHISE_CODE        899164 non-null  int64
#  15  IS_URBAN              899164 non-null  int64
#  16  IS_REVOLVER           894636 non-null  object
#  17  IS_LOW_DOC            896582 non-null  object
#  18  DEFAULT_DATE          162699 non-null  datetime64[ns]
#  19  DISBURSEMENT_DATE     896796 non-null  datetime64[ns]
#  20  DISBURSEMENT_AMOUNT   899164 non-null  object
#  21  BALANCE_AMOUNT        899164 non-null  object
#  22  LOAN_STATUS           897167 non-null  object
#  23  CHARGE_OFF_AMOUNT     899164 non-null  object
#  24  LOAN_AMOUNT           899164 non-null  object
#  25  SBA_APPROVED_AMOUNT   899164 non-null  object
#  26  TREASURY_YIELD        768092 non-null  float64
#  27  CPI_INDEX             768092 non-null  float64
#  28  GDP                   768092 non-null  float64
#  29  MORTGAGE_30_US_FIXED  768087 non-null  float64
#  30  UNRATE                768092 non-null  float64
#  31  INDPRO_INDEX          768092 non-null  float64
#  32  UMCSENT_INDEX         768092 non-null  float64
#  33  CSUSHPINSA_INDEX      757978 non-null  float64
#  34  CP_INDEX              768092 non-null  float64
#  35  FEDFUNDS_RATE         768092 non-null  float64
# dtypes: datetime64[ns](3), float64(11), int64(8), object(14)
# memory usage: 247.0+ MB

# %%
unprocessed_ld_df[['DISBURSEMENT_AMOUNT', 'CHARGE_OFF_AMOUNT', 'LOAN_AMOUNT', 'SBA_APPROVED_AMOUNT']] = unprocessed_ld_df[['DISBURSEMENT_AMOUNT', 'CHARGE_OFF_AMOUNT', 'LOAN_AMOUNT', 'SBA_APPROVED_AMOUNT']].replace('[\\$,]', '', regex=True).astype(float)

# %%
unprocessed_ld_df['IS_REVOLVER'] = unprocessed_ld_df['IS_REVOLVER'].map({'Y': True, 'N': False})
unprocessed_ld_df['IS_LOW_DOC'] = unprocessed_ld_df['IS_LOW_DOC'].map({'Y': True, 'N': False})
unprocessed_ld_df.head()
# Out:
#                     BORROWER_NAME                 CITY STATE    ZIP  \
# 0            SHANGRI LA HOTEL INC  ELLENVILLE      N Y    NY  12428
# 1              CATSKILL MILLS INC           WALTON N Y    NY  13856
# 2           TRYON COATS & LEATHER   JOHNSTOWN       NY   NaN      0
# 3  LOUIS GELBER & ELSIE RODRIGUEZ             BROOKLYN    NY  11029
# 4                CHARLENE R PAYNE             BOGALUSA    LA  70427
#
#                              BANK BANK_STATE  INDUSTRY_ID APPROVAL_DATE  \
# 0      BANK OF AMERICA NATL ASSOC         NY            0    1961-12-07
# 1  NBT BANK, NATIONAL ASSOCIATION         NY            0    1964-11-27
# 2    KEYBANK NATIONAL ASSOCIATION         NY            0    1966-05-18
# 3  GOVERNMENT DEVEL BK FOR PUERTO         PR            0    1967-02-28
# 4                    WHITNEY BANK         MS            0    1967-04-25
#
#   APPROVAL_YEAR  TERM  EMPLOYEE_COUNT  IS_NEW  JOBS_CREATED_COUNT  \
# 0          1962   300               0     0.0                   0
# 1          1965   252               0     0.0                   0
# 2          1966   282               0     0.0                   0
# 3          1967    72               0     0.0                   0
# 4          1967   228               4     0.0                   0
#
#    JOBS_RETAINED_COUNT  FRANCHISE_CODE  IS_URBAN IS_REVOLVER IS_LOW_DOC  \
# 0                    0               0         0       False      False
# 1                    0               0         0       False      False
# 2                    0               0         0       False      False
# 3                    0               0         0       False      False
# 4                    0               0         0       False      False
#
#   DEFAULT_DATE DISBURSEMENT_DATE  DISBURSEMENT_AMOUNT BALANCE_AMOUNT  \
# 0   1990-02-16               NaT                  0.0         $0.00
# 1   1989-04-03               NaT                  0.0         $0.00
# 2   1990-03-29        1966-08-16              60000.0         $0.00
# 3   1992-05-19               NaT                  0.0         $0.00
# 4   1989-03-15               NaT                  0.0         $0.00
#
#   LOAN_STATUS  CHARGE_OFF_AMOUNT  LOAN_AMOUNT  SBA_APPROVED_AMOUNT  \
# 0         NaN             2613.0     100000.0              90000.0
# 1         NaN            55625.0     150000.0             127500.0
# 2      CHGOFF             6084.0      60000.0              54000.0
# 3         NaN             8023.0      30000.0              15000.0
# 4         NaN             9915.0      45000.0              40500.0
#
#    TREASURY_YIELD  CPI_INDEX        GDP  MORTGAGE_30_US_FIXED    UNRATE  \
# 0        3.945833  30.253333  603.92150                   NaN  5.566667
# 1        4.282500  31.528333  742.29025                   NaN  4.508333
# 2        4.923333  32.470833  813.41375                   NaN  3.791667
# 3        5.073333  33.375000  859.95625                   NaN  3.841667
# 4             NaN        NaN        NaN                   NaN       NaN
#
#    INDPRO_INDEX  UMCSENT_INDEX  CSUSHPINSA_INDEX  CP_INDEX  FEDFUNDS_RATE
# 0     25.332875         95.475               NaN  35.90825       2.708333
# 1     31.546817        103.425               NaN  53.34175       4.075000
# 2     34.337933         93.800               NaN  58.15200       5.111667
# 3     35.079150         94.975               NaN  56.61175       4.220000
# 4           NaN            NaN               NaN       NaN            NaN

# %%
is_new_counts = unprocessed_ld_df['IS_NEW'].value_counts(dropna=False)
print("Frequency distribution of 'IS_NEW':")
print(is_new_counts)

is_urban_counts = unprocessed_ld_df['IS_URBAN'].value_counts(dropna=False)
print("\nFrequency distribution of 'IS_URBAN':")
print(is_urban_counts)
# Out:
# Frequency distribution of 'IS_NEW':
# IS_NEW
# 1.0    644869
# 2.0    253125
# 0.0      1034
# NaN       136
# Name: count, dtype: int64
#
# Frequency distribution of 'IS_URBAN':
# IS_URBAN
# 1    470654
# 0    323167
# 2    105343
# Name: count, dtype: int64

# %%
# Knowing this info above, we can assume the frequency distribution of urban loans and new loans to be more likely, meaning 1 is boolean true
unprocessed_ld_df['IS_NEW'] = unprocessed_ld_df['IS_NEW'].map({1.0: True, 2.0: False})
unprocessed_ld_df['IS_URBAN'] = unprocessed_ld_df['IS_URBAN'].map({1: True, 2: False})

# %%
unprocessed_ld_df['LOAN_STATUS'] = unprocessed_ld_df['LOAN_STATUS'].map({"CHGOFF": False, "P I F": True})

# %%
unprocessed_ld_df.head(10000000)
# Out:
#                          BORROWER_NAME                 CITY STATE    ZIP  \
# 0                 SHANGRI LA HOTEL INC  ELLENVILLE      N Y    NY  12428
# 1                   CATSKILL MILLS INC           WALTON N Y    NY  13856
# 2                TRYON COATS & LEATHER   JOHNSTOWN       NY   NaN      0
# 3       LOUIS GELBER & ELSIE RODRIGUEZ             BROOKLYN    NY  11029
# 4                     CHARLENE R PAYNE             BOGALUSA    LA  70427
# ...                                ...                  ...   ...    ...
# 899159      MARK DEMATTIA INCORPORATED            EWA BEACH    HI  96706
# 899160     PURSUIT SPORTS MEDICINE LLC             PORTLAND    OR  97232
# 899161  Face Reality, Inc., dba Face R          San Leandro    CA  94577
# 899162      HARDRIVES CONSTRUCTION INC             BILLINGS    MT  59103
# 899163        TEDDY JEMES TRUCKING LLC              LEBANON    MO  65536
#
#                                   BANK BANK_STATE  INDUSTRY_ID APPROVAL_DATE  \
# 0           BANK OF AMERICA NATL ASSOC         NY            0    1961-12-07
# 1       NBT BANK, NATIONAL ASSOCIATION         NY            0    1964-11-27
# 2         KEYBANK NATIONAL ASSOCIATION         NY            0    1966-05-18
# 3       GOVERNMENT DEVEL BK FOR PUERTO         PR            0    1967-02-28
# 4                         WHITNEY BANK         MS            0    1967-04-25
# ...                                ...        ...          ...           ...
# 899159            CENTRAL PACIFIC BANK         HI       492210    2014-06-12
# 899160  U.S. BANK NATIONAL ASSOCIATION         OH       621111    2014-06-18
# 899161              CITY NATIONAL BANK         CA       325412    2014-06-19
# 899162      BANK OF BRIDGER NATL ASSOC         MT       237310    2014-06-23
# 899163  U.S. BANK NATIONAL ASSOCIATION         OH       484230    2014-06-25
#
#        APPROVAL_YEAR  TERM  EMPLOYEE_COUNT IS_NEW  JOBS_CREATED_COUNT  \
# 0               1962   300               0    NaN                   0
# 1               1965   252               0    NaN                   0
# 2               1966   282               0    NaN                   0
# 3               1967    72               0    NaN                   0
# 4               1967   228               4    NaN                   0
# ...              ...   ...             ...    ...                 ...
# 899159          2014    60               0  False                   0
# 899160          2014    60               1   True                   0
# 899161          2014    84              15   True                   3
# 899162          2014     6              30   True                   0
# 899163          2014    60               1   True                   0
#
#         JOBS_RETAINED_COUNT  FRANCHISE_CODE IS_URBAN IS_REVOLVER IS_LOW_DOC  \
# 0                         0               0      NaN       False      False
# 1                         0               0      NaN       False      False
# 2                         0               0      NaN       False      False
# 3                         0               0      NaN       False      False
# 4                         0               0      NaN       False      False
# ...                     ...             ...      ...         ...        ...
# 899159                    0               0     True       False      False
# 899160                    1               0     True       False      False
# 899161                    0               0     True       False      False
# 899162                   30               0    False        True      False
# 899163                    0               0    False       False      False
#
#        DEFAULT_DATE DISBURSEMENT_DATE  DISBURSEMENT_AMOUNT BALANCE_AMOUNT  \
# 0        1990-02-16               NaT                  0.0         $0.00
# 1        1989-04-03               NaT                  0.0         $0.00
# 2        1990-03-29        1966-08-16              60000.0         $0.00
# 3        1992-05-19               NaT                  0.0         $0.00
# 4        1989-03-15               NaT                  0.0         $0.00
# ...             ...               ...                  ...            ...
# 899159          NaT        2014-06-12              50000.0         $0.00
# 899160          NaT        2014-06-18             165000.0         $0.00
# 899161          NaT        2014-06-19             150000.0         $0.00
# 899162          NaT        2014-06-23             210000.0         $0.00
# 899163          NaT        2014-06-25              13500.0         $0.00
#
#        LOAN_STATUS  CHARGE_OFF_AMOUNT  LOAN_AMOUNT  SBA_APPROVED_AMOUNT  \
# 0              NaN             2613.0     100000.0              90000.0
# 1              NaN            55625.0     150000.0             127500.0
# 2            False             6084.0      60000.0              54000.0
# 3              NaN             8023.0      30000.0              15000.0
# 4              NaN             9915.0      45000.0              40500.0
# ...            ...                ...          ...                  ...
# 899159        True                0.0      50000.0              25000.0
# 899160        True                0.0     165000.0              82500.0
# 899161        True                0.0     150000.0              75000.0
# 899162        True                0.0     210000.0             157500.0
# 899163        True                0.0      13500.0               6750.0
#
#         TREASURY_YIELD   CPI_INDEX          GDP  MORTGAGE_30_US_FIXED  \
# 0             3.945833   30.253333    603.92150                   NaN
# 1             4.282500   31.528333    742.29025                   NaN
# 2             4.923333   32.470833    813.41375                   NaN
# 3             5.073333   33.375000    859.95625                   NaN
# 4                  NaN         NaN          NaN                   NaN
# ...                ...         ...          ...                   ...
# 899159        2.540833  236.715000  17608.13825              4.168868
# 899160        2.540833  236.715000  17608.13825              4.168868
# 899161        2.540833  236.715000  17608.13825              4.168868
# 899162        2.540833  236.715000  17608.13825              4.168868
# 899163        2.540833  236.715000  17608.13825              4.168868
#
#           UNRATE  INDPRO_INDEX  UMCSENT_INDEX  CSUSHPINSA_INDEX    CP_INDEX  \
# 0       5.566667     25.332875         95.475               NaN    35.90825
# 1       4.508333     31.546817        103.425               NaN    53.34175
# 2       3.791667     34.337933         93.800               NaN    58.15200
# 3       3.841667     35.079150         94.975               NaN    56.61175
# 4            NaN           NaN            NaN               NaN         NaN
# ...          ...           ...            ...               ...         ...
# 899159  6.158333    102.305642         84.125        164.674667  1947.36300
# 899160  6.158333    102.305642         84.125        164.674667  1947.36300
# 899161  6.158333    102.305642         84.125        164.674667  1947.36300
# 899162  6.158333    102.305642         84.125        164.674667  1947.36300
# 899163  6.158333    102.305642         84.125        164.674667  1947.36300
#
#         FEDFUNDS_RATE
# 0            2.708333
# 1            4.075000
# 2            5.111667
# 3            4.220000
# 4                 NaN
# ...               ...
# 899159       0.089167
# 899160       0.089167
# 899161       0.089167
# 899162       0.089167
# 899163       0.089167
#
# [899164 rows x 36 columns]

# %%
processed_noReduced_ld_df = unprocessed_ld_df.copy()

# %%
economic_indicators = [
    'TREASURY_YIELD', 'CPI_INDEX', 'GDP', 'MORTGAGE_30_US_FIXED',
    'UNRATE', 'INDPRO_INDEX', 'UMCSENT_INDEX', 'CSUSHPINSA_INDEX',
    'CP_INDEX', 'FEDFUNDS_RATE'
]
processed_noReduced_ld_df = processed_noReduced_ld_df.dropna(subset=economic_indicators, how='all')
processed_noReduced_ld_df = processed_noReduced_ld_df[processed_noReduced_ld_df['APPROVAL_DATE'].dt.year >= 1990]
processed_noReduced_ld_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 737405 entries, 31172 to 899163
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   BORROWER_NAME         737391 non-null  object
#  1   CITY                  737405 non-null  object
#  2   STATE                 737401 non-null  object
#  3   ZIP                   737405 non-null  int64
#  4   BANK                  736565 non-null  object
#  5   BANK_STATE            736560 non-null  object
#  6   INDUSTRY_ID           737405 non-null  int64
#  7   APPROVAL_DATE         737405 non-null  datetime64[ns]
#  8   APPROVAL_YEAR         737405 non-null  object
#  9   TERM                  737405 non-null  int64
#  10  EMPLOYEE_COUNT        737405 non-null  int64
#  11  IS_NEW                736473 non-null  object
#  12  JOBS_CREATED_COUNT    737405 non-null  int64
#  13  JOBS_RETAINED_COUNT   737405 non-null  int64
#  14  FRANCHISE_CODE        737405 non-null  int64
#  15  IS_URBAN              507494 non-null  object
#  16  IS_REVOLVER           506557 non-null  object
#  17  IS_LOW_DOC            732976 non-null  object
#  18  DEFAULT_DATE          139138 non-null  datetime64[ns]
#  19  DISBURSEMENT_DATE     735396 non-null  datetime64[ns]
#  20  DISBURSEMENT_AMOUNT   737405 non-null  float64
#  21  BALANCE_AMOUNT        737405 non-null  object
#  22  LOAN_STATUS           735685 non-null  object
#  23  CHARGE_OFF_AMOUNT     737405 non-null  float64
#  24  LOAN_AMOUNT           737405 non-null  float64
#  25  SBA_APPROVED_AMOUNT   737405 non-null  float64
#  26  TREASURY_YIELD        737405 non-null  float64
#  27  CPI_INDEX             737405 non-null  float64
#  28  GDP                   737405 non-null  float64
#  29  MORTGAGE_30_US_FIXED  737405 non-null  float64
#  30  UNRATE                737405 non-null  float64
#  31  INDPRO_INDEX          737405 non-null  float64
#  32  UMCSENT_INDEX         737405 non-null  float64
#  33  CSUSHPINSA_INDEX      737405 non-null  float64
#  34  CP_INDEX              737405 non-null  float64
#  35  FEDFUNDS_RATE         737405 non-null  float64
# dtypes: datetime64[ns](3), float64(14), int64(7), object(12)
# memory usage: 208.2+ MB

# %%
processed_noReduced_ld_df = processed_noReduced_ld_df.dropna(subset=['INDUSTRY_ID'])

processed_noReduced_ld_df = processed_noReduced_ld_df.dropna(subset=['INDUSTRY_ID',
                                                                     'IS_NEW',
                                                                     'IS_URBAN',
                                                                     'LOAN_STATUS',
                                                                     'IS_REVOLVER',
                                                                     'BANK',
                                                                     'BORROWER_NAME', 
                                                                     'IS_LOW_DOC',
                                                                     'DISBURSEMENT_DATE'])

processed_noReduced_ld_df = processed_noReduced_ld_df[processed_noReduced_ld_df['DISBURSEMENT_AMOUNT'] != 0]

processed_noReduced_ld_df['APPROVAL_DATE'] = pd.to_datetime(processed_noReduced_ld_df['APPROVAL_DATE'], errors='coerce')
processed_noReduced_ld_df.head()
# Out:
#                          BORROWER_NAME     CITY STATE    ZIP  \
# 119522  JOHNSSON REESE FINANCIAL SOLUT  CHICAGO    IL  60622
# 119527   COMPUTERLAND OF DOWNERS GROVE  CHICAGO    IL  60515
# 119675       SEARS RETAIL DEALER STORE    SELMA    AL  36701
# 120580                        NICOLE'S  CHICAGO    IL  60622
# 121009                KID'S TIME, INC.   SKOKIE    IL  60618
#
#                               BANK BANK_STATE  INDUSTRY_ID APPROVAL_DATE  \
# 119522            FIFTH THIRD BANK         IL            0    1994-05-17
# 119527    BMO HARRIS BK NATL ASSOC         IL            0    1994-05-17
# 119675     TRUSTMARK NATIONAL BANK         AL            0    1994-05-19
# 120580  BANK OF AMERICA NATL ASSOC         IL            0    1994-05-31
# 121009  BANK OF AMERICA NATL ASSOC         IL       624410    1994-06-03
#
#        APPROVAL_YEAR  TERM  EMPLOYEE_COUNT IS_NEW  JOBS_CREATED_COUNT  \
# 119522          1994    36              16   True                   0
# 119527          1994    84               6   True                   0
# 119675          1994   120               3  False                   0
# 120580          1994    84               6   True                   0
# 121009          1994    84               1  False                   0
#
#         JOBS_RETAINED_COUNT  FRANCHISE_CODE IS_URBAN IS_REVOLVER IS_LOW_DOC  \
# 119522                    0               1     True       False      False
# 119527                    0           19110     True       False      False
# 119675                    0               1    False       False      False
# 120580                    0               1     True       False      False
# 121009                    0           45499     True       False      False
#
#        DEFAULT_DATE DISBURSEMENT_DATE  DISBURSEMENT_AMOUNT BALANCE_AMOUNT  \
# 119522          NaT        1994-10-31              20000.0         $0.00
# 119527          NaT        1994-10-31             250000.0         $0.00
# 119675          NaT        1994-07-31             213500.0         $0.00
# 120580          NaT        1994-07-31              75000.0         $0.00
# 121009          NaT        1994-10-31              60000.0         $0.00
#
#        LOAN_STATUS  CHARGE_OFF_AMOUNT  LOAN_AMOUNT  SBA_APPROVED_AMOUNT  \
# 119522        True                0.0      20000.0              18000.0
# 119527        True                0.0     250000.0             200000.0
# 119675        True                0.0     213500.0             181475.0
# 120580        True                0.0      75000.0              67500.0
# 121009        True                0.0      60000.0              54000.0
#
#         TREASURY_YIELD  CPI_INDEX        GDP  MORTGAGE_30_US_FIXED  UNRATE  \
# 119522            7.08    148.225  7287.2365              8.380769     6.1
# 119527            7.08    148.225  7287.2365              8.380769     6.1
# 119675            7.08    148.225  7287.2365              8.380769     6.1
# 120580            7.08    148.225  7287.2365              8.380769     6.1
# 121009            7.08    148.225  7287.2365              8.380769     6.1
#
#         INDPRO_INDEX  UMCSENT_INDEX  CSUSHPINSA_INDEX   CP_INDEX  \
# 119522     68.713433      92.266667         79.469083  438.35075
# 119527     68.713433      92.266667         79.469083  438.35075
# 119675     68.713433      92.266667         79.469083  438.35075
# 120580     68.713433      92.266667         79.469083  438.35075
# 121009     68.713433      92.266667         79.469083  438.35075
#
#         FEDFUNDS_RATE
# 119522       4.201667
# 119527       4.201667
# 119675       4.201667
# 120580       4.201667
# 121009       4.201667

# %%
processed_noReduced_ld_df = processed_noReduced_ld_df[processed_noReduced_ld_df['DISBURSEMENT_AMOUNT'] != 0]
processed_noReduced_ld_df.head(1000000000000000)
# Out:
#                          BORROWER_NAME         CITY STATE    ZIP  \
# 119522  JOHNSSON REESE FINANCIAL SOLUT      CHICAGO    IL  60622
# 119527   COMPUTERLAND OF DOWNERS GROVE      CHICAGO    IL  60515
# 119675       SEARS RETAIL DEALER STORE        SELMA    AL  36701
# 120580                        NICOLE'S      CHICAGO    IL  60622
# 121009                KID'S TIME, INC.       SKOKIE    IL  60618
# ...                                ...          ...   ...    ...
# 899159      MARK DEMATTIA INCORPORATED    EWA BEACH    HI  96706
# 899160     PURSUIT SPORTS MEDICINE LLC     PORTLAND    OR  97232
# 899161  Face Reality, Inc., dba Face R  San Leandro    CA  94577
# 899162      HARDRIVES CONSTRUCTION INC     BILLINGS    MT  59103
# 899163        TEDDY JEMES TRUCKING LLC      LEBANON    MO  65536
#
#                                   BANK BANK_STATE  INDUSTRY_ID APPROVAL_DATE  \
# 119522                FIFTH THIRD BANK         IL            0    1994-05-17
# 119527        BMO HARRIS BK NATL ASSOC         IL            0    1994-05-17
# 119675         TRUSTMARK NATIONAL BANK         AL            0    1994-05-19
# 120580      BANK OF AMERICA NATL ASSOC         IL            0    1994-05-31
# 121009      BANK OF AMERICA NATL ASSOC         IL       624410    1994-06-03
# ...                                ...        ...          ...           ...
# 899159            CENTRAL PACIFIC BANK         HI       492210    2014-06-12
# 899160  U.S. BANK NATIONAL ASSOCIATION         OH       621111    2014-06-18
# 899161              CITY NATIONAL BANK         CA       325412    2014-06-19
# 899162      BANK OF BRIDGER NATL ASSOC         MT       237310    2014-06-23
# 899163  U.S. BANK NATIONAL ASSOCIATION         OH       484230    2014-06-25
#
#        APPROVAL_YEAR  TERM  EMPLOYEE_COUNT IS_NEW  JOBS_CREATED_COUNT  \
# 119522          1994    36              16   True                   0
# 119527          1994    84               6   True                   0
# 119675          1994   120               3  False                   0
# 120580          1994    84               6   True                   0
# 121009          1994    84               1  False                   0
# ...              ...   ...             ...    ...                 ...
# 899159          2014    60               0  False                   0
# 899160          2014    60               1   True                   0
# 899161          2014    84              15   True                   3
# 899162          2014     6              30   True                   0
# 899163          2014    60               1   True                   0
#
#         JOBS_RETAINED_COUNT  FRANCHISE_CODE IS_URBAN IS_REVOLVER IS_LOW_DOC  \
# 119522                    0               1     True       False      False
# 119527                    0           19110     True       False      False
# 119675                    0               1    False       False      False
# 120580                    0               1     True       False      False
# 121009                    0           45499     True       False      False
# ...                     ...             ...      ...         ...        ...
# 899159                    0               0     True       False      False
# 899160                    1               0     True       False      False
# 899161                    0               0     True       False      False
# 899162                   30               0    False        True      False
# 899163                    0               0    False       False      False
#
#        DEFAULT_DATE DISBURSEMENT_DATE  DISBURSEMENT_AMOUNT BALANCE_AMOUNT  \
# 119522          NaT        1994-10-31              20000.0         $0.00
# 119527          NaT        1994-10-31             250000.0         $0.00
# 119675          NaT        1994-07-31             213500.0         $0.00
# 120580          NaT        1994-07-31              75000.0         $0.00
# 121009          NaT        1994-10-31              60000.0         $0.00
# ...             ...               ...                  ...            ...
# 899159          NaT        2014-06-12              50000.0         $0.00
# 899160          NaT        2014-06-18             165000.0         $0.00
# 899161          NaT        2014-06-19             150000.0         $0.00
# 899162          NaT        2014-06-23             210000.0         $0.00
# 899163          NaT        2014-06-25              13500.0         $0.00
#
#        LOAN_STATUS  CHARGE_OFF_AMOUNT  LOAN_AMOUNT  SBA_APPROVED_AMOUNT  \
# 119522        True                0.0      20000.0              18000.0
# 119527        True                0.0     250000.0             200000.0
# 119675        True                0.0     213500.0             181475.0
# 120580        True                0.0      75000.0              67500.0
# 121009        True                0.0      60000.0              54000.0
# ...            ...                ...          ...                  ...
# 899159        True                0.0      50000.0              25000.0
# 899160        True                0.0     165000.0              82500.0
# 899161        True                0.0     150000.0              75000.0
# 899162        True                0.0     210000.0             157500.0
# 899163        True                0.0      13500.0               6750.0
#
#         TREASURY_YIELD  CPI_INDEX          GDP  MORTGAGE_30_US_FIXED  \
# 119522        7.080000    148.225   7287.23650              8.380769
# 119527        7.080000    148.225   7287.23650              8.380769
# 119675        7.080000    148.225   7287.23650              8.380769
# 120580        7.080000    148.225   7287.23650              8.380769
# 121009        7.080000    148.225   7287.23650              8.380769
# ...                ...        ...          ...                   ...
# 899159        2.540833    236.715  17608.13825              4.168868
# 899160        2.540833    236.715  17608.13825              4.168868
# 899161        2.540833    236.715  17608.13825              4.168868
# 899162        2.540833    236.715  17608.13825              4.168868
# 899163        2.540833    236.715  17608.13825              4.168868
#
#           UNRATE  INDPRO_INDEX  UMCSENT_INDEX  CSUSHPINSA_INDEX    CP_INDEX  \
# 119522  6.100000     68.713433      92.266667         79.469083   438.35075
# 119527  6.100000     68.713433      92.266667         79.469083   438.35075
# 119675  6.100000     68.713433      92.266667         79.469083   438.35075
# 120580  6.100000     68.713433      92.266667         79.469083   438.35075
# 121009  6.100000     68.713433      92.266667         79.469083   438.35075
# ...          ...           ...            ...               ...         ...
# 899159  6.158333    102.305642      84.125000        164.674667  1947.36300
# 899160  6.158333    102.305642      84.125000        164.674667  1947.36300
# 899161  6.158333    102.305642      84.125000        164.674667  1947.36300
# 899162  6.158333    102.305642      84.125000        164.674667  1947.36300
# 899163  6.158333    102.305642      84.125000        164.674667  1947.36300
#
#         FEDFUNDS_RATE
# 119522       4.201667
# 119527       4.201667
# 119675       4.201667
# 120580       4.201667
# 121009       4.201667
# ...               ...
# 899159       0.089167
# 899160       0.089167
# 899161       0.089167
# 899162       0.089167
# 899163       0.089167
#
# [328305 rows x 36 columns]

# %%
processed_noReduced_ld_df = processed_noReduced_ld_df[processed_noReduced_ld_df['INDUSTRY_ID'] != 0]

# %%
processed_row_reduced_ld_df = processed_noReduced_ld_df.copy()

# %%
processed_row_reduced_ld_df = processed_row_reduced_ld_df.drop(columns=['CITY', 'BALANCE_AMOUNT'])

# %%
processed_row_reduced_ld_df = processed_row_reduced_ld_df.reset_index(drop = True)
processed_row_reduced_ld_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319455 entries, 0 to 319454
# Data columns (total 34 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   BORROWER_NAME         319455 non-null  object
#  1   STATE                 319455 non-null  object
#  2   ZIP                   319455 non-null  int64
#  3   BANK                  319455 non-null  object
#  4   BANK_STATE            319455 non-null  object
#  5   INDUSTRY_ID           319455 non-null  int64
#  6   APPROVAL_DATE         319455 non-null  datetime64[ns]
#  7   APPROVAL_YEAR         319455 non-null  object
#  8   TERM                  319455 non-null  int64
#  9   EMPLOYEE_COUNT        319455 non-null  int64
#  10  IS_NEW                319455 non-null  object
#  11  JOBS_CREATED_COUNT    319455 non-null  int64
#  12  JOBS_RETAINED_COUNT   319455 non-null  int64
#  13  FRANCHISE_CODE        319455 non-null  int64
#  14  IS_URBAN              319455 non-null  object
#  15  IS_REVOLVER           319455 non-null  object
#  16  IS_LOW_DOC            319455 non-null  object
#  17  DEFAULT_DATE          90988 non-null   datetime64[ns]
#  18  DISBURSEMENT_DATE     319455 non-null  datetime64[ns]
#  19  DISBURSEMENT_AMOUNT   319455 non-null  float64
#  20  LOAN_STATUS           319455 non-null  object
#  21  CHARGE_OFF_AMOUNT     319455 non-null  float64
#  22  LOAN_AMOUNT           319455 non-null  float64
#  23  SBA_APPROVED_AMOUNT   319455 non-null  float64
#  24  TREASURY_YIELD        319455 non-null  float64
#  25  CPI_INDEX             319455 non-null  float64
#  26  GDP                   319455 non-null  float64
#  27  MORTGAGE_30_US_FIXED  319455 non-null  float64
#  28  UNRATE                319455 non-null  float64
#  29  INDPRO_INDEX          319455 non-null  float64
#  30  UMCSENT_INDEX         319455 non-null  float64
#  31  CSUSHPINSA_INDEX      319455 non-null  float64
#  32  CP_INDEX              319455 non-null  float64
#  33  FEDFUNDS_RATE         319455 non-null  float64
# dtypes: datetime64[ns](3), float64(14), int64(7), object(10)
# memory usage: 82.9+ MB

# %%
processed_row_reduced_ld_df['EXPOSURE'] = processed_row_reduced_ld_df['DISBURSEMENT_AMOUNT'] -  processed_row_reduced_ld_df['SBA_APPROVED_AMOUNT']
processed_row_reduced_ld_df['PERCENTAGE_EXPOSURE'] = processed_row_reduced_ld_df['EXPOSURE']/processed_row_reduced_ld_df ['DISBURSEMENT_AMOUNT']

# %%
processed_row_reduced_ld_df.head()
# Out:
#                   BORROWER_NAME STATE    ZIP                            BANK  \
# 0              KID'S TIME, INC.    IL  60618      BANK OF AMERICA NATL ASSOC
# 1         DERHAM & REEVES, EA'S    CA  94538     WELLS FARGO BANK NATL ASSOC
# 2  TEMPORARY LIVING OF COLUMBUS    OH  43231  JPMORGAN CHASE BANK NATL ASSOC
# 3             BALOONS AND BEARS    CA  94598     WELLS FARGO BANK NATL ASSOC
# 4            BALLOONS AND BEARS    CA  94566     WELLS FARGO BANK NATL ASSOC
#
#   BANK_STATE  INDUSTRY_ID APPROVAL_DATE APPROVAL_YEAR  TERM  EMPLOYEE_COUNT  \
# 0         IL       624410    1994-06-03          1994    84               1
# 1         SD       541213    1995-11-24          1996    84               2
# 2         IL       721310    1995-12-15          1996    84               1
# 3         SD       453220    1996-01-11          1996    84               1
# 4         SD       453220    1996-01-11          1996    84               3
#
#   IS_NEW  JOBS_CREATED_COUNT  JOBS_RETAINED_COUNT  FRANCHISE_CODE IS_URBAN  \
# 0  False                   0                    0           45499     True
# 1   True                   0                    0               1     True
# 2  False                   0                    0               1     True
# 3  False                   0                    0            8047     True
# 4  False                   0                    0            8047     True
#
#   IS_REVOLVER IS_LOW_DOC DEFAULT_DATE DISBURSEMENT_DATE  DISBURSEMENT_AMOUNT  \
# 0       False      False          NaT        1994-10-31              60000.0
# 1       False      False          NaT        1996-01-31              24000.0
# 2       False      False          NaT        1996-01-31             140000.0
# 3       False      False   2003-04-15        1996-04-30              46200.0
# 4       False      False          NaT        1996-04-30              50000.0
#
#   LOAN_STATUS  CHARGE_OFF_AMOUNT  LOAN_AMOUNT  SBA_APPROVED_AMOUNT  \
# 0        True                0.0      60000.0              54000.0
# 1        True                0.0      24000.0              19200.0
# 2        True                0.0     140000.0             105000.0
# 3       False            19329.0      46200.0              36960.0
# 4        True                0.0      50000.0              40000.0
#
#    TREASURY_YIELD   CPI_INDEX         GDP  MORTGAGE_30_US_FIXED    UNRATE  \
# 0        7.080000  148.225000  7287.23650              8.380769  6.100000
# 1        6.438333  156.858333  8073.12175              7.806154  5.408333
# 2        6.438333  156.858333  8073.12175              7.806154  5.408333
# 3        6.438333  156.858333  8073.12175              7.806154  5.408333
# 4        6.438333  156.858333  8073.12175              7.806154  5.408333
#
#    INDPRO_INDEX  UMCSENT_INDEX  CSUSHPINSA_INDEX   CP_INDEX  FEDFUNDS_RATE  \
# 0     68.713433      92.266667         79.469083  438.35075       4.201667
# 1     75.165983      93.608333         82.808500  541.42850       5.298333
# 2     75.165983      93.608333         82.808500  541.42850       5.298333
# 3     75.165983      93.608333         82.808500  541.42850       5.298333
# 4     75.165983      93.608333         82.808500  541.42850       5.298333
#
#    EXPOSURE  PERCENTAGE_EXPOSURE
# 0    6000.0                 0.10
# 1    4800.0                 0.20
# 2   35000.0                 0.25
# 3    9240.0                 0.20
# 4   10000.0                 0.20
